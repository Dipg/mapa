# %%
import folium
from folium import GeoJson
from folium.plugins import MarkerCluster

# %%
geo=r"datos.json"
file = open(geo, encoding="utf8")
text = file.read()
GeoJson(text).add_to(m)



folium_map = folium.Map(location=[-2.9005954757079273, -79.01016100881519],
                        zoom_start=17,)

marker_cluster = MarkerCluster().add_to(folium_map)

pub_html = folium.Html(f"""<p style="text-align: center;"><span style="font-family: Didot, serif; font-size: 21px;">Hola</span></p>
    <p style="text-align: center;"><iframe src="https://scontent.fuio13-1.fna.fbcdn.net/v/t1.6435-9/36846655_646067285785970_4797000834908946432_n.jpg?_nc_cat=106&ccb=1-5&_nc_sid=e3f864&_nc_ohc=5NSQ-MbkxA8AX_mNRze&_nc_ht=scontent.fuio13-1.fna&oh=9213d59245cbfce67f0d52f6fe638d47&oe=61B38BE1" embed width="240" height="290" frameborder="0" scrolling="no" allowtransparency="true"></iframe>
    """, script=True)
    
    
marker = folium.CircleMarker(location=[-2.9005954757079273, -79.01016100881519],radius=20, fill_color='red',tooltip='Universidad de Cuenca', popup="<stong>Allianz Arena</stong>")
marker.add_to(folium_map).add_to(marker_cluster)
marker2 = folium.CircleMarker(location=[-2.90046330959323, -79.01134534682340],radius=40, fill_color='red',tooltip='Universidad de Cuenca',popup = folium.Popup(pub_html, max_width=700))
marker2.add_to(folium_map).add_to(marker_cluster)
marker3 = folium.CircleMarker(location=[-2.900529729989930, -79.00986276974780],radius=30, fill_color='blue',tooltip='Universidad de Cuenca',popup = folium.Popup(pub_html, max_width=700))
marker3.add_to(folium_map).add_to(marker_cluster)
marker4 = folium.CircleMarker(location=[-2.901113680223950, -79.0097217679389],radius=25, fill_color='blue',tooltip='Universidad de Cuenca',popup = folium.Popup(pub_html, max_width=700))
marker4.add_to(folium_map).add_to(marker_cluster)

marker4 = folium.CircleMarker(location=[-2.901113680223950, -79.0097217679389],radius=25, fill_color='blue',tooltip='Universidad de Cuenca',popup = folium.Popup(pub_html, max_width=700))
marker4.add_to(folium_map).add_to(marker_cluster)

GeoJson(text,).add_to(folium_map)

folium.TileLayer('Stamen Terrain').add_to(folium_map)
folium.TileLayer('Stamen Toner').add_to(folium_map)
folium.TileLayer('Stamen Water Color').add_to(folium_map)
folium.TileLayer('cartodbpositron').add_to(folium_map)
folium.TileLayer('cartodbdark_matter').add_to(folium_map)
folium.LayerControl().add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
folium_map.save("my_map.html")
